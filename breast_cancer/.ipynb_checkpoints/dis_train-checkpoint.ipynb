# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import torch.nn.functional as F
import matplotlib.pyplot as plt
import os
from sklearn.metrics import accuracy_score
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
# Teacher Model
class TeacherNetwork(nn.Module):
    def __init__(self, num_classes=10):
        super(TeacherNetwork, self).__init__()
        self.backbone1 = models.resnet152(pretrained=True)
        self.feature_extractor1 = nn.Sequential(*list(self.backbone1.children())[:-2])
        self.feature_extractor2 = nn.Sequential(*list(self.backbone1.children())[:-50])
        self.feature_extractor3 = nn.Sequential(*list(self.backbone1.children())[:-100])
        self.global_pool = nn.AdaptiveAvgPool2d(1)
        self.local_pool = nn.AdaptiveAvgPool2d((4, 4))
        self.fc1 = nn.Linear(34816, 256)
        self.fc2 = nn.Linear(51, 256)
        self.fc3 = nn.Linear(51, 256)
        self.fc_out1 = nn.Linear(256, num_classes)
        self.fc_out2 = nn.Linear(256, num_classes)
        self.fc_out3 = nn.Linear(256, num_classes)
        self.fc_out_final = nn.Linear(6, num_classes)

    def forward(self, x):
        features1 = self.feature_extractor1(x)
        global_features1 = self.global_pool(features1).view(x.size(0), -1)
        local_features1 = self.local_pool(features1).view(x.size(0), -1)
        combined_features1 = torch.cat((global_features1, local_features1), dim=1)

        features2 = self.feature_extractor2(x)
        global_features2 = self.global_pool(features2).view(x.size(0), -1)
        local_features2 = self.local_pool(features2).view(x.size(0), -1)
        combined_features2 = torch.cat((global_features2, local_features2), dim=1)

        features3 = self.feature_extractor3(x)
        global_features3 = self.global_pool(features3).view(x.size(0), -1)
        local_features3 = self.local_pool(features3).view(x.size(0), -1)
        combined_features3 = torch.cat((global_features3, local_features3), dim=1)

        out1 = self.fc_out1(self.fc1(combined_features1))
        out2 = self.fc_out2(self.fc2(combined_features2))
        out3 = self.fc_out3(self.fc3(combined_features3))
        out_cat = torch.cat((out1, out2, out3), dim=1)
        final_out = self.fc_out_final(out_cat)
        return final_out, out1, out2, out3

# Student Model
class StudentNetwork(nn.Module):
    def __init__(self, num_classes=10):
        super(StudentNetwork, self).__init__()
        self.backbone = models.mobilenet_v2(pretrained=True)
        for param in self.backbone.parameters():
            param.requires_grad = True
        self.backbone.classifier[1] = nn.Linear(self.backbone.last_channel, num_classes)

    def forward(self, x):
        out = self.backbone(x)
        return out

# Distillation Loss Function
def distillation_loss(student_outputs, teacher_outputs, temperature=2.0):
    student_prob = F.softmax(student_outputs / temperature, dim=1)
    teacher_prob = F.softmax(teacher_outputs / temperature, dim=1)
    loss = F.kl_div(student_prob.log(), teacher_prob, reduction='batchmean')
    return loss

# Total Loss (Combination of Classification Loss and Distillation Loss)
def total_loss(student_output, teacher_output, target, temperature=2.0, alpha=0.5):
    classification_loss = F.cross_entropy(student_output, target)
    distill_loss = distillation_loss(student_output, teacher_output, temperature)
    loss = alpha * classification_loss + (1 - alpha) * distill_loss
    return loss

# Training Loop
def train(student_model, teacher_model, dataloader, optimizer, temperature=2.0, alpha=0.5):
    student_model.train()
    teacher_model.eval()
    
    running_loss = 0.0
    all_preds = []
    all_labels = []
    
    for inputs, labels in dataloader:
        inputs, labels = inputs.cuda(), labels.cuda()
        
        # Forward pass through teacher
        with torch.no_grad():
            teacher_outputs, _, _, _ = teacher_model(inputs)
        
        # Forward pass through student
        student_outputs = student_model(inputs)
        
        # Compute the total loss (classification + distillation)
        loss = total_loss(student_outputs, teacher_outputs, labels, temperature, alpha)
        
        # Zero gradients, backprop, and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        # Collect predictions and labels for accuracy
        _, predicted = torch.max(student_outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    
    # Calculate training accuracy
    train_accuracy = accuracy_score(all_labels, all_preds)
    return running_loss / len(dataloader), train_accuracy

# Validation Loop
def validate(student_model, dataloader):
    student_model.eval()
    
    running_loss = 0.0
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.cuda(), labels.cuda()
            
            student_outputs = student_model(inputs)
            loss = F.cross_entropy(student_outputs, labels)
            running_loss += loss.item()
            
            # Collect predictions and labels for accuracy
            _, predicted = torch.max(student_outputs, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    # Calculate validation accuracy
    val_accuracy = accuracy_score(all_labels, all_preds)
    return running_loss / len(dataloader), val_accuracy

# Save best model checkpoint
def save_checkpoint(model, epoch, val_acc,f):
    checkpoint_path="./checkpoints/"+ str(f)+"_best_model.pth"
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'val_accuracy': val_acc,
    }, checkpoint_path)

# Example usage
if __name__ == '__main__':
    teacher_model = TeacherNetwork(num_classes=2).cuda()
    teacher_model_ckpt = "./checkpoints/best_model_res152_dif_p1.pth"
    teacher_model.load_state_dict(torch.load(teacher_model_ckpt))
    student_model = StudentNetwork(num_classes=2).cuda()

    optimizer = optim.Adam(student_model.parameters(), lr=0.00005)

    # Data preparation (use your own dataset path)
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    train_set = datasets.ImageFolder(root="./syn_vision_dataset/train", transform=transform)
    val_set = datasets.ImageFolder(root="./syn_vision_dataset/val", transform=transform)

    train_loader = DataLoader(train_set, batch_size=28, shuffle=True)
    val_loader = DataLoader(val_set, batch_size=1, shuffle=False)

    best_val_acc = 0.0
    num_epochs =100
    train_losses = []
    train_accuracies = []
    val_losses = []
    val_accuracies = []
    k=0
    for epoch in range(num_epochs):
        train_loss, train_acc = train(student_model, teacher_model, train_loader, optimizer, temperature=2.0, alpha=0.5)
        val_loss, val_acc = validate(student_model, val_loader)

        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)
        k = k+1
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')
        if k>69:        
            save_checkpoint(student_model, epoch, best_val_acc,k)
#         # Save best model based on validation accuracy
#         if val_acc > best_val_acc:        
#             best_val_acc = val_acc
#             save_checkpoint(student_model, epoch, best_val_acc)

    # Plotting the metrics
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(range(1, num_epochs+1), train_losses, label='Train Loss')
    plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss Progress')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(range(1, num_epochs+1), train_accuracies, label='Train Accuracy')
    plt.plot(range(1, num_epochs+1), val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Accuracy Progress')
    plt.legend()

    plt.tight_layout()
    plt.savefig('training_progress.png')
    plt.show()
# Out:
# /home/philipslinux/anaconda3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/philipslinux/anaconda3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /tmp/ipykernel_35086/295099930.py:155: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher_model.load_state_dict(torch.load(teacher_model_ckpt))
# /home/philipslinux/anaconda3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch [1/100], Train Loss: 0.2436, Train Acc: 0.8787, Val Loss: 0.2358, Val Acc: 0.9725
# Epoch [2/100], Train Loss: 0.1093, Train Acc: 0.9336, Val Loss: 0.1372, Val Acc: 0.9541
# Epoch [3/100], Train Loss: 0.0776, Train Acc: 0.9634, Val Loss: 0.1364, Val Acc: 0.9541
# Epoch [4/100], Train Loss: 0.0545, Train Acc: 0.9817, Val Loss: 0.1462, Val Acc: 0.9541
# Epoch [5/100], Train Loss: 0.0534, Train Acc: 0.9771, Val Loss: 0.1627, Val Acc: 0.9541
# Epoch [6/100], Train Loss: 0.0333, Train Acc: 0.9954, Val Loss: 0.1459, Val Acc: 0.9541
# Epoch [7/100], Train Loss: 0.0349, Train Acc: 0.9931, Val Loss: 0.1614, Val Acc: 0.9450
# Epoch [8/100], Train Loss: 0.0320, Train Acc: 0.9977, Val Loss: 0.1498, Val Acc: 0.9541
# Epoch [9/100], Train Loss: 0.0389, Train Acc: 0.9863, Val Loss: 0.1574, Val Acc: 0.9450
# Epoch [10/100], Train Loss: 0.0307, Train Acc: 0.9977, Val Loss: 0.1518, Val Acc: 0.9450
# Epoch [11/100], Train Loss: 0.0319, Train Acc: 0.9954, Val Loss: 0.1613, Val Acc: 0.9450
# Epoch [12/100], Train Loss: 0.0271, Train Acc: 1.0000, Val Loss: 0.1443, Val Acc: 0.9450
# Epoch [13/100], Train Loss: 0.0286, Train Acc: 0.9954, Val Loss: 0.1482, Val Acc: 0.9450
# Epoch [14/100], Train Loss: 0.0260, Train Acc: 1.0000, Val Loss: 0.1350, Val Acc: 0.9450
# Epoch [15/100], Train Loss: 0.0268, Train Acc: 0.9977, Val Loss: 0.1456, Val Acc: 0.9541
# Epoch [16/100], Train Loss: 0.0272, Train Acc: 0.9977, Val Loss: 0.1465, Val Acc: 0.9450
# Epoch [17/100], Train Loss: 0.0287, Train Acc: 1.0000, Val Loss: 0.1482, Val Acc: 0.9450
# Epoch [18/100], Train Loss: 0.0258, Train Acc: 0.9977, Val Loss: 0.1495, Val Acc: 0.9450
# Epoch [19/100], Train Loss: 0.0277, Train Acc: 0.9977, Val Loss: 0.1472, Val Acc: 0.9541
# Epoch [20/100], Train Loss: 0.0260, Train Acc: 1.0000, Val Loss: 0.1576, Val Acc: 0.9450
# Epoch [21/100], Train Loss: 0.0291, Train Acc: 1.0000, Val Loss: 0.1465, Val Acc: 0.9450
# Epoch [22/100], Train Loss: 0.0264, Train Acc: 1.0000, Val Loss: 0.1408, Val Acc: 0.9450
# Epoch [23/100], Train Loss: 0.0242, Train Acc: 1.0000, Val Loss: 0.1435, Val Acc: 0.9450
# Epoch [24/100], Train Loss: 0.0237, Train Acc: 1.0000, Val Loss: 0.1530, Val Acc: 0.9450
# Epoch [25/100], Train Loss: 0.0251, Train Acc: 1.0000, Val Loss: 0.1470, Val Acc: 0.9450
# Epoch [26/100], Train Loss: 0.0250, Train Acc: 1.0000, Val Loss: 0.1393, Val Acc: 0.9450
# Epoch [27/100], Train Loss: 0.0227, Train Acc: 0.9977, Val Loss: 0.1376, Val Acc: 0.9450
# Epoch [28/100], Train Loss: 0.0229, Train Acc: 1.0000, Val Loss: 0.1403, Val Acc: 0.9450
# Epoch [29/100], Train Loss: 0.0235, Train Acc: 1.0000, Val Loss: 0.1397, Val Acc: 0.9450
# Epoch [30/100], Train Loss: 0.0242, Train Acc: 1.0000, Val Loss: 0.1436, Val Acc: 0.9450
# Epoch [31/100], Train Loss: 0.0224, Train Acc: 1.0000, Val Loss: 0.1423, Val Acc: 0.9450
# Epoch [32/100], Train Loss: 0.0263, Train Acc: 0.9977, Val Loss: 0.1480, Val Acc: 0.9450
# Epoch [33/100], Train Loss: 0.0237, Train Acc: 1.0000, Val Loss: 0.1425, Val Acc: 0.9541
# Epoch [34/100], Train Loss: 0.0235, Train Acc: 1.0000, Val Loss: 0.1370, Val Acc: 0.9450
# Epoch [35/100], Train Loss: 0.0226, Train Acc: 1.0000, Val Loss: 0.1355, Val Acc: 0.9450
# Epoch [36/100], Train Loss: 0.0222, Train Acc: 1.0000, Val Loss: 0.1405, Val Acc: 0.9450
# Epoch [37/100], Train Loss: 0.0246, Train Acc: 0.9977, Val Loss: 0.1333, Val Acc: 0.9450
# Epoch [38/100], Train Loss: 0.0229, Train Acc: 1.0000, Val Loss: 0.1383, Val Acc: 0.9450
# Epoch [39/100], Train Loss: 0.0233, Train Acc: 1.0000, Val Loss: 0.1322, Val Acc: 0.9450
# Epoch [40/100], Train Loss: 0.0233, Train Acc: 1.0000, Val Loss: 0.1396, Val Acc: 0.9450
# Epoch [41/100], Train Loss: 0.0239, Train Acc: 0.9977, Val Loss: 0.1417, Val Acc: 0.9450
# Epoch [42/100], Train Loss: 0.0251, Train Acc: 1.0000, Val Loss: 0.1414, Val Acc: 0.9541
# Epoch [43/100], Train Loss: 0.0239, Train Acc: 1.0000, Val Loss: 0.1464, Val Acc: 0.9358
# Epoch [44/100], Train Loss: 0.0237, Train Acc: 1.0000, Val Loss: 0.1406, Val Acc: 0.9450
# Epoch [45/100], Train Loss: 0.0226, Train Acc: 1.0000, Val Loss: 0.1410, Val Acc: 0.9450
# Epoch [46/100], Train Loss: 0.0228, Train Acc: 1.0000, Val Loss: 0.1400, Val Acc: 0.9450
# Epoch [47/100], Train Loss: 0.0231, Train Acc: 1.0000, Val Loss: 0.1374, Val Acc: 0.9450
# Epoch [48/100], Train Loss: 0.0231, Train Acc: 1.0000, Val Loss: 0.1344, Val Acc: 0.9541
# Epoch [49/100], Train Loss: 0.0221, Train Acc: 1.0000, Val Loss: 0.1342, Val Acc: 0.9450
# Epoch [50/100], Train Loss: 0.0238, Train Acc: 1.0000, Val Loss: 0.1300, Val Acc: 0.9450
# Epoch [51/100], Train Loss: 0.0235, Train Acc: 1.0000, Val Loss: 0.1343, Val Acc: 0.9450
# Epoch [52/100], Train Loss: 0.0230, Train Acc: 1.0000, Val Loss: 0.1362, Val Acc: 0.9450
# Epoch [53/100], Train Loss: 0.0232, Train Acc: 1.0000, Val Loss: 0.1383, Val Acc: 0.9450
# Epoch [54/100], Train Loss: 0.0219, Train Acc: 1.0000, Val Loss: 0.1376, Val Acc: 0.9450
# Epoch [55/100], Train Loss: 0.0222, Train Acc: 1.0000, Val Loss: 0.1357, Val Acc: 0.9450
# Epoch [56/100], Train Loss: 0.0221, Train Acc: 1.0000, Val Loss: 0.1292, Val Acc: 0.9450
# Epoch [57/100], Train Loss: 0.0220, Train Acc: 1.0000, Val Loss: 0.1354, Val Acc: 0.9450
# Epoch [58/100], Train Loss: 0.0220, Train Acc: 1.0000, Val Loss: 0.1417, Val Acc: 0.9450
# Epoch [59/100], Train Loss: 0.0226, Train Acc: 1.0000, Val Loss: 0.1268, Val Acc: 0.9450
# Epoch [60/100], Train Loss: 0.0232, Train Acc: 1.0000, Val Loss: 0.1332, Val Acc: 0.9450
# Epoch [61/100], Train Loss: 0.0233, Train Acc: 1.0000, Val Loss: 0.1381, Val Acc: 0.9450
# Epoch [62/100], Train Loss: 0.0240, Train Acc: 1.0000, Val Loss: 0.1313, Val Acc: 0.9450
# Epoch [63/100], Train Loss: 0.0224, Train Acc: 1.0000, Val Loss: 0.1344, Val Acc: 0.9450
# Epoch [64/100], Train Loss: 0.0230, Train Acc: 1.0000, Val Loss: 0.1311, Val Acc: 0.9450
# Epoch [65/100], Train Loss: 0.0219, Train Acc: 1.0000, Val Loss: 0.1351, Val Acc: 0.9450
# Epoch [66/100], Train Loss: 0.0229, Train Acc: 1.0000, Val Loss: 0.1387, Val Acc: 0.9450
# Epoch [67/100], Train Loss: 0.0237, Train Acc: 1.0000, Val Loss: 0.1374, Val Acc: 0.9541
# Epoch [68/100], Train Loss: 0.0236, Train Acc: 1.0000, Val Loss: 0.1369, Val Acc: 0.9450
# Epoch [69/100], Train Loss: 0.0231, Train Acc: 1.0000, Val Loss: 0.1265, Val Acc: 0.9450
# Epoch [70/100], Train Loss: 0.0235, Train Acc: 1.0000, Val Loss: 0.1265, Val Acc: 0.9541
# Epoch [71/100], Train Loss: 0.0231, Train Acc: 1.0000, Val Loss: 0.1256, Val Acc: 0.9541
# Epoch [72/100], Train Loss: 0.0230, Train Acc: 0.9977, Val Loss: 0.1342, Val Acc: 0.9450
# Epoch [73/100], Train Loss: 0.0226, Train Acc: 1.0000, Val Loss: 0.1432, Val Acc: 0.9450
# Epoch [74/100], Train Loss: 0.0217, Train Acc: 1.0000, Val Loss: 0.1413, Val Acc: 0.9450
# Epoch [75/100], Train Loss: 0.0217, Train Acc: 1.0000, Val Loss: 0.1362, Val Acc: 0.9450
# Epoch [76/100], Train Loss: 0.0217, Train Acc: 1.0000, Val Loss: 0.1337, Val Acc: 0.9450
# Epoch [77/100], Train Loss: 0.0228, Train Acc: 1.0000, Val Loss: 0.1395, Val Acc: 0.9450
# Epoch [78/100], Train Loss: 0.0223, Train Acc: 1.0000, Val Loss: 0.1321, Val Acc: 0.9450
# Epoch [79/100], Train Loss: 0.0221, Train Acc: 1.0000, Val Loss: 0.1367, Val Acc: 0.9450
# Epoch [80/100], Train Loss: 0.0223, Train Acc: 1.0000, Val Loss: 0.1352, Val Acc: 0.9450
# Epoch [81/100], Train Loss: 0.0219, Train Acc: 1.0000, Val Loss: 0.1357, Val Acc: 0.9450
# Epoch [82/100], Train Loss: 0.0214, Train Acc: 1.0000, Val Loss: 0.1346, Val Acc: 0.9450
# Epoch [83/100], Train Loss: 0.0217, Train Acc: 1.0000, Val Loss: 0.1306, Val Acc: 0.9450
# Epoch [84/100], Train Loss: 0.0218, Train Acc: 1.0000, Val Loss: 0.1342, Val Acc: 0.9450
# Epoch [85/100], Train Loss: 0.0209, Train Acc: 1.0000, Val Loss: 0.1353, Val Acc: 0.9450
# Epoch [86/100], Train Loss: 0.0218, Train Acc: 1.0000, Val Loss: 0.1347, Val Acc: 0.9450
# Epoch [87/100], Train Loss: 0.0219, Train Acc: 1.0000, Val Loss: 0.1335, Val Acc: 0.9450
# Epoch [88/100], Train Loss: 0.0215, Train Acc: 1.0000, Val Loss: 0.1308, Val Acc: 0.9450
# Epoch [89/100], Train Loss: 0.0221, Train Acc: 1.0000, Val Loss: 0.1293, Val Acc: 0.9450
# Epoch [90/100], Train Loss: 0.0222, Train Acc: 1.0000, Val Loss: 0.1364, Val Acc: 0.9450
# Epoch [91/100], Train Loss: 0.0219, Train Acc: 1.0000, Val Loss: 0.1300, Val Acc: 0.9450
# Epoch [92/100], Train Loss: 0.0223, Train Acc: 1.0000, Val Loss: 0.1275, Val Acc: 0.9541
# Epoch [93/100], Train Loss: 0.0217, Train Acc: 1.0000, Val Loss: 0.1348, Val Acc: 0.9450
# Epoch [94/100], Train Loss: 0.0207, Train Acc: 1.0000, Val Loss: 0.1342, Val Acc: 0.9450
# Epoch [95/100], Train Loss: 0.0221, Train Acc: 1.0000, Val Loss: 0.1327, Val Acc: 0.9450
# Epoch [96/100], Train Loss: 0.0215, Train Acc: 1.0000, Val Loss: 0.1312, Val Acc: 0.9450
# Epoch [97/100], Train Loss: 0.0218, Train Acc: 1.0000, Val Loss: 0.1359, Val Acc: 0.9450
# Epoch [98/100], Train Loss: 0.0218, Train Acc: 1.0000, Val Loss: 0.1356, Val Acc: 0.9450
# Epoch [99/100], Train Loss: 0.0213, Train Acc: 1.0000, Val Loss: 0.1317, Val Acc: 0.9450
# Epoch [100/100], Train Loss: 0.0213, Train Acc: 1.0000, Val Loss: 0.1331, Val Acc: 0.9450
