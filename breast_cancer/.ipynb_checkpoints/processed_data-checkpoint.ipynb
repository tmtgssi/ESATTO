# %%
import timeit
import numpy as np 
import pandas as pd 
import progressbar
start = timeit.default_timer()
file_name = "./tabular_dataset/breast-cancer-wisconsin.csv"
df = pd.read_csv(file_name)
print(df.isnull().values.any())
# Out:
# False

# %%
df.columns
# Out:
# Index(['id', ' Clump Thickness', 'Uniformity of Cell Size',
#        'Uniformity of Cell Shape', 'Marginal Adhesion',
#        'Single Epithelial Cell Size', 'Bare Nuclei', 'Bland Chromatin',
#        'Normal Nucleoli', 'Mitoses', 'Class'],
#       dtype='object')

# %%
df
# Out:
#           id   Clump Thickness  Uniformity of Cell Size  \
# 0    1000025                 5                        1
# 1    1002945                 5                        4
# 2    1015425                 3                        1
# 3    1016277                 6                        8
# 4    1017023                 4                        1
# ..       ...               ...                      ...
# 678   776715                 3                        1
# 679   841769                 2                        1
# 680   888820                 5                       10
# 681   897471                 4                        8
# 682   897471                 4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           1                  1                            2
# 1                           4                  5                            7
# 2                           1                  1                            2
# 3                           8                  1                            3
# 4                           1                  3                            2
# ..                        ...                ...                          ...
# 678                         1                  1                            3
# 679                         1                  1                            2
# 680                        10                  3                            7
# 681                         6                  4                            3
# 682                         8                  5                            4
#
#      Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0              1                3                1        1      2
# 1             10                3                2        1      2
# 2              2                3                1        1      2
# 3              4                3                7        1      2
# 4              1                3                1        1      2
# ..           ...              ...              ...      ...    ...
# 678            2                1                1        1      2
# 679            1                1                1        1      2
# 680            3                8               10        2      4
# 681            4               10                6        1      4
# 682            5               10                4        1      4
#
# [683 rows x 11 columns]

# %%
i=0
for typ in df.Class.unique():    
    df.loc[df["Class"]==typ,"Class"]=i
    print(typ, i)
    i=i+1
print(df)
# Out:
# 2 0
# 4 1
#           id   Clump Thickness  Uniformity of Cell Size  \
# 0    1000025                 5                        1
# 1    1002945                 5                        4
# 2    1015425                 3                        1
# 3    1016277                 6                        8
# 4    1017023                 4                        1
# ..       ...               ...                      ...
# 678   776715                 3                        1
# 679   841769                 2                        1
# 680   888820                 5                       10
# 681   897471                 4                        8
# 682   897471                 4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           1                  1                            2
# 1                           4                  5                            7
# 2                           1                  1                            2
# 3                           8                  1                            3
# 4                           1                  3                            2
# ..                        ...                ...                          ...
# 678                         1                  1                            3
# 679                         1                  1                            2
# 680                        10                  3                            7
# 681                         6                  4                            3
# 682                         8                  5                            4
#
#      Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0              1                3                1        1      0
# 1             10                3                2        1      0
# 2              2                3                1        1      0
# 3              4                3                7        1      0
# 4              1                3                1        1      0
# ..           ...              ...              ...      ...    ...
# 678            2                1                1        1      0
# 679            1                1                1        1      0
# 680            3                8               10        2      1
# 681            4               10                6        1      1
# 682            5               10                4        1      1
#
# [683 rows x 11 columns]

# %%
df
# Out:
#           id   Clump Thickness  Uniformity of Cell Size  \
# 0    1000025                 5                        1
# 1    1002945                 5                        4
# 2    1015425                 3                        1
# 3    1016277                 6                        8
# 4    1017023                 4                        1
# ..       ...               ...                      ...
# 678   776715                 3                        1
# 679   841769                 2                        1
# 680   888820                 5                       10
# 681   897471                 4                        8
# 682   897471                 4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           1                  1                            2
# 1                           4                  5                            7
# 2                           1                  1                            2
# 3                           8                  1                            3
# 4                           1                  3                            2
# ..                        ...                ...                          ...
# 678                         1                  1                            3
# 679                         1                  1                            2
# 680                        10                  3                            7
# 681                         6                  4                            3
# 682                         8                  5                            4
#
#      Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0              1                3                1        1      0
# 1             10                3                2        1      0
# 2              2                3                1        1      0
# 3              4                3                7        1      0
# 4              1                3                1        1      0
# ..           ...              ...              ...      ...    ...
# 678            2                1                1        1      0
# 679            1                1                1        1      0
# 680            3                8               10        2      1
# 681            4               10                6        1      1
# 682            5               10                4        1      1
#
# [683 rows x 11 columns]

# %%
df = df.drop(columns=['id'])

# %%
df
# Out:
#       Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                   5                        1                         1
# 1                   5                        4                         4
# 2                   3                        1                         1
# 3                   6                        8                         8
# 4                   4                        1                         1
# ..                ...                      ...                       ...
# 678                 3                        1                         1
# 679                 2                        1                         1
# 680                 5                       10                        10
# 681                 4                        8                         6
# 682                 4                        8                         8
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 0                    1                            2            1
# 1                    5                            7           10
# 2                    1                            2            2
# 3                    1                            3            4
# 4                    3                            2            1
# ..                 ...                          ...          ...
# 678                  1                            3            2
# 679                  1                            2            1
# 680                  3                            7            3
# 681                  4                            3            4
# 682                  5                            4            5
#
#      Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0                  3                1        1      0
# 1                  3                2        1      0
# 2                  3                1        1      0
# 3                  3                7        1      0
# 4                  3                1        1      0
# ..               ...              ...      ...    ...
# 678                1                1        1      0
# 679                1                1        1      0
# 680                8               10        2      1
# 681               10                6        1      1
# 682               10                4        1      1
#
# [683 rows x 10 columns]

# %%
df.dtypes
# Out:
#  Clump Thickness               int64
# Uniformity of Cell Size        int64
# Uniformity of Cell Shape       int64
# Marginal Adhesion              int64
# Single Epithelial Cell Size    int64
# Bare Nuclei                    int64
# Bland Chromatin                int64
# Normal Nucleoli                int64
# Mitoses                        int64
# Class                          int64
# dtype: object

# %%
df.to_csv('./tabular_dataset/trieu_data_processed.csv', index=False)
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# Time:  0.0613727950003522
